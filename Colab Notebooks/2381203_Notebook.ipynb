# %% [markdown]
# Kametay Turar - 2381203 - February 2, 2024

# %%
import numpy
import matplotlib

# %% [markdown]
# **Task 1.1:**

# %%
x = 345
result = 2*x+5**3
print(result)
# Out:
# 815

# %%
print("Hello World")
# Out:
# Hello World

# %%
def f(w,x,b):
  result = w*x + b
  print(result)
f(345,2,5**3)
# Out:
# 815

# %% [markdown]
# **Task 1.2:**

# %%
my_list = ["hey", "i", "am", "running", "the", "code"]
print(my_list)
# Out:
# ['hey', 'i', 'am', 'running', 'the', 'code']

# %%
for i in my_list[::-1]:
  print(i)
# Out:
# code
# the
# running
# am
# i
# hey

# %%
def equals_100(x):
  if x == 100:
    print(True)
  else:
    print(False)
equals_100(100)
equals_100(99)
# Out:
# True
# False

# %%
my_dictionary = {
    "data_name":"Animal counts",
    "label":['cat','dog','fish'],
    "count":[2,5,10]
}
print(my_dictionary["count"])
# Out:
# [2, 5, 10]

# %%
print(f'Animal name: {my_dictionary["label"][1]}, count: {my_dictionary["count"][1]}')
# Out:
# Animal name: dog, count: 5

# %% [markdown]
# **Task 1.3**

# %%
a=numpy.random.randint(0,9, size=(2,3))
b=numpy.random.randint(0,9, size=(3,4))
print(a)
print(b)
# Out:
# [[2 3 6]
#  [3 0 1]]
# [[6 7 8 6]
#  [0 1 7 2]
#  [5 2 7 7]]

# %%
c = numpy.matmul(a,b)
print(c)
# Out:
# [[42 29 79 60]
#  [23 23 31 25]]

# %%
print(c[:,0])
# Out:
# [42 23]

# %% [markdown]
# **Task 1.4**

# %%
iris = numpy.load('/content/drive/MyDrive/Colab/Iris_data.npy')

# %%
print(numpy.shape(iris))
# Out:
# (150, 4)

# %%
matplotlib.pyplot.scatter(iris[:,0],iris[:,1])
matplotlib.pyplot.title("Fisher Iris Scatter Plot")
matplotlib.pyplot.xlabel("Sepal Width")
matplotlib.pyplot.ylabel("Sepal Length")
matplotlib.pyplot.show()
